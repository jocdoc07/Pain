# %% [markdown]
# <a href="https://colab.research.google.com/github/jocdoc07/Pain/blob/main/NHIS_Adult_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data <- read.csv("/adult22.csv")

# %%
dim(adult22.csv)
# Out:
# Error: object 'adult22.csv' not found
# Traceback:

# %%
dim(data)
# Out:
# [1] 27651   637

# %%
head(data)
# Out:
#   URBRRL RATCAT_A INCTCFLG_A IMPINCFLG_A SHOTTYPE1_A CEVOTELC_A CEMMETNG_A
# 1 2       7       0          0           NA          NA         NA
# 2 4      14       0          0           NA          NA         NA
# 3 4      14       0          0           NA          NA         NA
# 4 4      11       0          0           NA          NA         NA
# 5 1       2       0          1           NA          NA         NA
# 6 1      14       0          1           NA          NA         NA
#   CEVOLUN2_A CEVOLUN1_A HITTEST_A ⋯ PROXYREL_A PROXY_A AVAIL_A HHSTAT_A
# 1 NA         NA         NA        ⋯ NA         NA      1       1
# 2 NA         NA         NA        ⋯ NA         NA      1       1
# 3 NA         NA         NA        ⋯ NA         NA      1       1
# 4 NA         NA         NA        ⋯ NA         NA      1       1
# 5 NA         NA         NA        ⋯  2          1      3       1
# 6 NA         NA         NA        ⋯ NA         NA      1       1
# ...

# %%
summary(data)
# Out:
#      URBRRL        RATCAT_A        INCTCFLG_A    IMPINCFLG_A
#  Min.   :1.00   Min.   : 1.000   Min.   :0.00   Min.   :0.0000
#  1st Qu.:1.00   1st Qu.: 7.000   1st Qu.:0.00   1st Qu.:0.0000
#  Median :2.00   Median :11.000   Median :0.00   Median :0.0000
#  Mean   :2.32   Mean   : 9.826   Mean   :0.04   Mean   :0.3689
#  3rd Qu.:3.00   3rd Qu.:14.000   3rd Qu.:0.00   3rd Qu.:0.0000
#  Max.   :4.00   Max.   :14.000   Max.   :1.00   Max.   :2.0000
#
#   SHOTTYPE1_A      CEVOTELC_A      CEMMETNG_A      CEVOLUN2_A
#  Min.   :1.000   Min.   :1.000   Min.   :1.000   Min.   :1.000
#  1st Qu.:1.000   1st Qu.:1.000   1st Qu.:2.000   1st Qu.:2.000
#  Median :1.000   Median :1.000   Median :2.000   Median :2.000
#  Mean   :1.722   Mean   :1.798   Mean   :2.193   Mean   :1.945
#  3rd Qu.:2.000   3rd Qu.:2.000   3rd Qu.:2.000   3rd Qu.:2.000
#  Max.   :9.000   Max.   :9.000   Max.   :9.000   Max.   :9.000
#  NA's   :22147   NA's   :13631   NA's   :13631   NA's   :17294
# ...

# %%
shapiro.test(agep_a)
# Out:
# Error: object 'agep_a' not found
# Traceback:
#
# 1. stopifnot(is.numeric(x))
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'agep_a' not found", base::quote(eval(expr, envir)))

# %%
# Assuming 'agep_a' is a column in the 'data' dataframe
agep_a <- data$agep_a  # Extract the 'agep_a' column from the dataframe

# Now you can use 'agep_a' in the shapiro.test function
shapiro.test(agep_a)
# Out:
# Error in shapiro.test(agep_a): is.numeric(x) is not TRUE
# Traceback:
#
# 1. stopifnot(is.numeric(x))
# 2. stop(simpleError(msg, call = if (p <- sys.parent(1L)) sys.call(p)))

# %%
shapiro.test(AGEP_A)
# Out:
# Error: object 'AGEP_A' not found
# Traceback:
#
# 1. stopifnot(is.numeric(x))
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'AGEP_A' not found", base::quote(eval(expr, envir)))

# %%
Age <- data$AGEP_A

# %%
shapiro.test(Age)
# Out:
# Error in shapiro.test(Age): sample size must be between 3 and 5000
# Traceback:
#
# 1. stop("sample size must be between 3 and 5000")
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "sample size must be between 3 and 5000", base::quote(shapiro.test(Age)))

# %%
length(Age)
# Out:
# [1] 27651

# %%
y = hist(x=Age)
# Out:
# Plot with title “Histogram of Age”
